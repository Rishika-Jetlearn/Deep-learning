# %%
from tkinter import*
from tensorflow.keras.models import load_model
import numpy as np
from PIL import Image,ImageDraw

# %%
model=load_model("digit_recogniser.h5")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
window=Tk()
window.title("Digit Recogniser")

def draw(event):
    x,y=event.x,event.y
    canvas.create_oval(x-5,y-5,x+5,y+5,fill="white",outline="white",width=3)
    draw_object.ellipse([x-5,y-5,x+5,y+5],fill=255)

def clearing():
    global image,draw_object
    image=Image.new("L",(500,500),color="black")
    draw_object=ImageDraw.Draw(image)
    label.config(text="Draw a digit")
    canvas.delete("all")

def predict():
    resized=image.resize((28,28))
    resized=np.array(resized)/255
    img=np.expand_dims(resized,axis=0)
    prediction=model.predict(img)
    final=np.argmax(prediction)
    label.config(text=final)

#canvas
canvas=Canvas(window,width=500,height=500,bg="black")
canvas.grid(row=0,column=0,padx=3,pady=3)
canvas.bind("<B1-Motion>",draw)

label=Label(window,text="Draw a digit")
label.grid(row=0,column=1)

predict_button=Button(window,text="Predict",command=predict)
predict_button.grid(row=1,column=1)

clear_button=Button(window,text="clear",command=clearing)
clear_button.grid(row=1,column=0)
#creating image
image=Image.new("L",(500,500),color="black")
draw_object=ImageDraw.Draw(image)
window.mainloop()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
