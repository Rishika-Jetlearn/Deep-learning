# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Flatten,Dropout
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.callbacks import LearningRateScheduler, EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np

# %%
(Xtr,ytr),(Xts,yts)=mnist.load_data()
Xtr=Xtr/255
Xts=Xts/255

# %%
print(Xtr.shape)
# Out:
# (60000, 28, 28)

# %%
#reshape to 4D
Xtr=Xtr.reshape(Xtr.shape[0],28,28,1)
print(Xtr.shape)
Xts=Xts.reshape(Xts.shape[0],28,28,1)
# Out:
# (60000, 28, 28, 1)

# %%
idg = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1,
    shear_range=0.1,
    brightness_range=[0.9, 1.1]
)

# %%
initial_learning_rate=0.01
batch_size=64
epochs=20
def lr_schedule(epoch,lr):
    if epoch>0 and epoch%3==0:
        return lr/2
    return lr

# %%
model=Sequential([
    Flatten(input_shape=(28,28)),
    Dense(128,activation="relu"),
    Dropout(0.3),
    Dense(64,activation="relu"),
    Dropout(0.3),
    Dense(10,activation="softmax")
]
)
# Out:
# c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
ytr=to_categorical(ytr,10)
yts=to_categorical(yts,10)

optimizer=SGD(learning_rate=initial_learning_rate)
model.compile(optimizer=optimizer,loss="categorical_crossentropy",metrics=["accuracy"])
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
#Early stopping
er=EarlyStopping(
    monitor="val_loss",
    patience=5,
    restore_best_weights=True

)

# %%
lr_scheduler=LearningRateScheduler(lr_schedule)
history=model.fit(Xtr,ytr,
          batch_size=batch_size,
          epochs=epochs,
          validation_data=(Xts,yts),
          callbacks=[lr_scheduler,er])
# Out:
# Epoch 1/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.5837 - loss: 1.3019 - val_accuracy: 0.8602 - val_loss: 0.5399 - learning_rate: 0.0100
# Epoch 2/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7957 - loss: 0.6691 - val_accuracy: 0.9016 - val_loss: 0.3700 - learning_rate: 0.0100
# Epoch 3/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8420 - loss: 0.5267 - val_accuracy: 0.9126 - val_loss: 0.3102 - learning_rate: 0.0100
# Epoch 4/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8632 - loss: 0.4658 - val_accuracy: 0.9186 - val_loss: 0.2884 - learning_rate: 0.0050
# Epoch 5/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8722 - loss: 0.4401 - val_accuracy: 0.9230 - val_loss: 0.2726 - learning_rate: 0.0050
# Epoch 6/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8781 - loss: 0.4171 - val_accuracy: 0.9247 - val_loss: 0.2598 - learning_rate: 0.0050
# Epoch 7/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8830 - loss: 0.3995 - val_accuracy: 0.9259 - val_loss: 0.2537 - learning_rate: 0.0025
# Epoch 8/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8833 - loss: 0.3946 - val_accuracy: 0.9279 - val_loss: 0.2478 - learning_rate: 0.0025
# Epoch 9/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8872 - loss: 0.3844 - val_accuracy: 0.9291 - val_loss: 0.2418 - learning_rate: 0.0025
# Epoch 10/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8909 - loss: 0.3719 - val_accuracy: 0.9301 - val_loss: 0.2396 - learning_rate: 0.0012
# Epoch 11/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8922 - loss: 0.3704 - val_accuracy: 0.9308 - val_loss: 0.2373 - learning_rate: 0.0012
# Epoch 12/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8936 - loss: 0.3662 - val_accuracy: 0.9306 - val_loss: 0.2346 - learning_rate: 0.0012
# Epoch 13/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8932 - loss: 0.3675 - val_accuracy: 0.9307 - val_loss: 0.2335 - learning_rate: 6.2500e-04
# Epoch 14/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8946 - loss: 0.3623 - val_accuracy: 0.9313 - val_loss: 0.2323 - learning_rate: 6.2500e-04
# Epoch 15/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8960 - loss: 0.3589 - val_accuracy: 0.9319 - val_loss: 0.2315 - learning_rate: 6.2500e-04
# Epoch 16/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8948 - loss: 0.3599 - val_accuracy: 0.9318 - val_loss: 0.2307 - learning_rate: 3.1250e-04
# Epoch 17/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8970 - loss: 0.3567 - val_accuracy: 0.9320 - val_loss: 0.2303 - learning_rate: 3.1250e-04
# Epoch 18/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8955 - loss: 0.3572 - val_accuracy: 0.9319 - val_loss: 0.2296 - learning_rate: 3.1250e-04
# Epoch 19/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8962 - loss: 0.3565 - val_accuracy: 0.9322 - val_loss: 0.2293 - learning_rate: 1.5625e-04
# Epoch 20/20
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8963 - loss: 0.3540 - val_accuracy: 0.9321 - val_loss: 0.2291 - learning_rate: 1.5625e-04

# %%
test_loss,test_accuracy=model.evaluate(Xts,yts)
print(test_loss,test_accuracy)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9321 - loss: 0.2291
# 0.22908827662467957 0.9320999979972839

# %%
import matplotlib.pyplot as plt
plt.plot(history.history["accuracy"],label="Train Data Accuracy")
plt.plot(history.history["val_accuracy"],label="Validation Accuracy")
plt.legend()
plt.xlabel("epochs")
plt.ylabel("Accuracy")
plt.show()

# %%
plt.plot(history.history["loss"],label="Loss")
plt.plot(history.history["val_loss"],label="Validation loss")
plt.legend()
plt.xlabel("ephocs")
plt.ylabel("Loss")
plt.show()
